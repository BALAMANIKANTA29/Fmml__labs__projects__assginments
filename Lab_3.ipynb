# %% [markdown]
# <a href="https://colab.research.google.com/github/BALAMANIKANTA29/Fmml__labs__projects__assginments/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 14:33:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   114MB/s    in 0.6s
#
# 2025-03-13 14:33:04 (114 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22308  1512.07666v1  Effective training of deep neural networks suf...  stat
# 3366   1605.06265v2  In this paper, we introduce a new image repres...  stat
# 25764  1511.05879v2  Recently, image representation built upon Conv...    cs
# 5487    1406.7758v1  Bayesian optimisation has gained great popular...  stat
# 36917  1510.02045v1  We give a detailed characterization of optimal...    cs
# ...             ...                                                ...   ...
# 31424  1803.03420v1  Brightfield and fluorescent imaging of whole b...    cs
# 11322  1509.05113v2  We consider the problem of learning the prefer...  stat
# 4902   1611.08070v1  This work presents a multiscale framework to s...    cs
# 26730  1611.07573v1  The Earth Mover's Distance (EMD) computes the ...    cs
# 5419    1210.1190v1  The separability assumption (Donoho & Stodden,...  stat
#
#                                                    title  year  \
# 22308  Preconditioned Stochastic Gradient Langevin Dy...  2015
# 3366   End-to-End Kernel Learning with Supervised Con...  2016
# 25764  Particular object retrieval with integral max-...  2015
# 5487   Theoretical Analysis of Bayesian Optimisation ...  2014
# 36917           Budget Constraints in Prediction Markets  2015
# ...                                                  ...   ...
# 31424  Robust Landmark Detection for Alignment of Mou...  2018
# 11322  Revealed Preference at Scale: Learning Persona...  2015
# 4902   Multiscale Inverse Reinforcement Learning usin...  2016
# 26730  Relaxed Earth Mover's Distances for Chain- and...  2016
# 5419   Fast Conical Hull Algorithms for Near-separabl...  2012
#
#                                                 keywords
# 22308  [effective, parameter, pathological, curvature...
# 3366   [introduce, representation, multilayer, tradit...
# 25764  [representation, convolutional, effective, des...
# 5487   [optimisation, popularity, optimising, paramet...
# 36917  [characterization, constraints, prediction, au...
# ...                                                  ...
# 31424  [brightfield, fluorescent, sectioning, efficie...
# 11322  [preferences, heterogeneous, population, obser...
# 4902   [multiscale, framework, reinforcement, continu...
# 26730  [transforming, distribution, transport, inform...
# 5419   [separability, assumption, factorization, trac...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22308    [effective, parameter, pathological, curvature...
# 3366     [introduce, representation, multilayer, tradit...
# 25764    [representation, convolutional, effective, des...
# 5487     [optimisation, popularity, optimising, paramet...
# 36917    [characterization, constraints, prediction, au...
#                                ...
# 20664    [knowledge, applications, recommender, configu...
# 33396    [multilayer, feedforward, direction, attention...
# 7052     [probabilistic, framework, nonlinearities, tru...
# 2853     [advertising, advertisers, impression, maximiz...
# 32764    [generalization, performance, classification, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8806 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="009c7654-8291-4497-9013-15302ff75fc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("009c7654-8291-4497-9013-15302ff75fc7")) {                    Plotly.newPlot(                        "009c7654-8291-4497-9013-15302ff75fc7",                        [{"x":["typically","demonstrating","empirical","curvature","asymptotic","overfitting","stochastic","performance","addressed","feedforward","averaging","inefficient","combining","properties","predictive","demonstrated","mitigates","theoretical","convolutional","preconditioned","preconditioning","effective","posterior","regression","convergence","parameter","pathological","unsupervised","introduced","traditional","representation","prediction","equivalent","reproducing","proposing","introduce","classification","applicability","supervised","competitive","reasonably","backpropagation","decoupled","supervision","multilayer","resolution","improvements","resulting","advantage","optimizing","efficiently","benchmarks","descriptor","expansion","activations","particular","compatible","employing","competing","representations","descriptors","challenging","recognition","outperformed","furthermore","outperforming","geometric","retrieval","primitive","information","significantly","guidelines","popularity","surprisingly","acquisition","notoriously","optimisation","algorithms","solutions","simulation","literature","cumulative","parameters","following","importance","optimising","estimation","reasonable","demonstrates","improvement","observation","processes","practical","application","generalization","understand","construct","corresponding","quadratic","independent","logarithmic","additivity","descriptively","constraints","individual","coordinates","sufficient","automated","characterization","conditions","associated","classified","clustered","different","classical","combination","improving","accessing","auxiliary","completely","necessary","searching","algorithm","techniques","considering","clustering","documents","abstraction","technique","available","description","quantized","excellent","augmentation","remarkable","projections","projection","quantization","including","multiplicative","projected","projecting","heuristic","robustness","specifically","binarization","distortions","distributions","passenger","extrapolation","smoothing","interpolation","framework","synthetic","covariances","atmospheric","discovering","reconstruct","performing","stationary","transform","functions","inference","demonstrate","modelling","nonparametric","discovery","structures","increasing","optimization","pyramidal","disappearance","important","gradually","experiments","structure","analysing","incoherent","principle","performed","transmission","characteristic","respectively","effectively","characteristics","therefore","quantified","analyzing","presenting","knowledge","quantitatively","generative","realistic","conditioned","dimensional","evaluation","intensive","generator","illustrate","degradation"],"y":[82,28,146,8,27,26,129,878,35,24,18,15,112,232,45,111,2,178,369,0,2,279,55,136,96,119,4,147,116,181,341,221,53,8,16,337,532,36,207,123,8,18,5,54,15,117,104,168,100,47,138,117,37,18,21,274,12,39,26,232,43,263,382,24,165,34,58,100,6,731,284,14,18,34,33,6,25,611,151,80,132,9,222,81,96,6,212,33,61,169,57,100,137,233,104,55,101,125,29,118,21,1,2,153,126,15,73,97,30,145,100,19,11,729,103,138,134,6,19,36,87,38,856,375,65,140,66,21,277,290,70,8,38,30,23,19,54,22,248,15,17,6,67,100,179,12,10,103,2,0,22,19,559,135,3,2,25,28,77,25,76,212,225,547,40,13,60,134,103,304,3,2,372,18,630,362,12,7,52,106,11,27,95,112,95,165,6,67,19,336,22,120,68,18,166,251,34,32,74,15],"type":"bar"},{"x":["typically","demonstrating","empirical","curvature" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 1.0);'>Utilisation</span> <span style=''>des</span> <span style=''>grammaires</span> <span style=''>probabilistes</span> <span style=''>dans</span> <span style=''>les</span> <span style=''>tâches</span> <span style=''>de</span> <span style='background-color:rgba(0, 255, 0, 0.7719298245614035);'>segmentation</span> <span style=''>et</span> <span style=''>dannotation</span> <span style=''>prosodique</span> <br/><br/><span style=''>Nous</span> <span style=''>presentons</span> <span style=''>dans</span> <span style=''>cette</span> <span style='background-color:rgba(0, 255, 0, 0.3378378378378379);'>contribution</span> <span style=''>une</span> <span style=''>approche</span> <span style=''>a</span> <span style=''>la</span> <span style=''>fois</span> <span style=''>symbolique</span> <span style=''>et</span> <span style=''>probabiliste</span> <span style=''>permettant</span> <span style=''>dextraire</span> <span style=''>linformation</span> <span style=''>sur</span> <span style=''>la</span> <span style='background-color:rgba(0, 255, 0, 0.7719298245614035);'>segmentation</span> <span style=''>du</span> <span style=''>signal</span> <span style=''>de</span> <span style=''>parole</span> <span style=''>a</span> <span style=''>partir</span> <span style=''>dinformation</span> <span style=''>prosodique</span> <span style=''>Nous</span> <span style=''>utilisons</span> <span style=''>pour</span> <span style=''>ce</span> <span style=''>faire</span> <span style=''>des</span> <span style=''>grammaires</span> <span style=''>probabilistes</span> <span style=''>possedant</span> <span style=''>une</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>hierarchique</span> <span style=''>minimale</span> <span style=''>La</span> <span style=''>phase</span> <span style=''>de</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>des</span> <span style=''>grammaires</span> <span style=''>ainsi</span> <span style=''>que</span> <span style=''>leur</span> <span style=''>pouvoir</span> <span style=''>de</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>sont</span> <span style=''>evalues</span> <span style=''>qualitativement</span> <span style=''>ainsi</span> <span style=''>que</span> <span style=''>quantitativement</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Methodologically</span> <span style=''>oriented</span> <span style=''>the</span> <span style=''>present</span> <span style=''>work</span> <span style=''>sketches</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>prosodic</span> <span style='background-color:rgba(0, 255, 0, 0.3266787658802177);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.6129032258064516);'>retrieval</span> <span style=''>and</span> <span style=''>speech</span> <span style='background-color:rgba(0, 255, 0, 0.7719298245614035);'>segmentation</span> <span style=''>based</span> <span style=''>on</span> <span style=''>both</span> <span style=''>symbolic</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3266787658802177);'>information</span> <span style=''>We</span> <span style=''>have</span> <span style=''>recourse</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>grammars</span> <span style=''>within</span> <span style=''>which</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implement</span> <span style=''>a</span> <span style=''>minimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>Both</span> <span style=''>the</span> <span style=''>stages</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>note</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>view</span> <span style=''>of</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <br/><br/><span style=''>A</span> <span style=''>very</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>Combined</span> <span style=''>with</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>results</span> <span style=''>from</span> <span style=''>missing</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicates</span> <span style=''>that</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>is</span> <span style=''>still</span> <span style=''>a</span> <span style=''>valid</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>even</span> <span style=''>without</span> <span style=''>the</span> <span style=''>missing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completely</span> <span style=''>at</span> <span style=''>random</span> <span style=''>(MCAR)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>which</span> <span style=''>almost</span> <span style=''>all</span> <span style=''>of</span> <span style=''>the</span> <span style=''>current</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>studies</span> <span style=''>of</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>assume</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style=''>Time</span> <span style=''>Bounds</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>widely</span> <span style=''>both</span> <span style=''>as</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>and</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>the</span> <span style=''>emphk</span> <span style=''>median</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>in</span> <span style=''>which</span> <span style=''>we</span> <span style=''>attempt</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>average</span> <span style=''>distance</span> <span style=''>to</span> <span style=''>cluster</span> <span style=''>centers</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributions</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>but</span> <span style=''>powerful</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>we</span> <span style=''>call</span> <span style=''>emphsuccessive</span> <span style=''>sampling</span> <span style=''>that</span> <span style=''>could</span> <span style=''>be</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>interest</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>can</span> <span style=''>rapidly</span> <span style=''>identify</span> <span style=''>a</span> <span style=''>small</span> <span style=''>set</span> <span style=''>of</span> <span style=''>points</span> <span style=''>(of</span> <span style=''>size</span> <span style=''>just</span> <span style=''>O(klognk))</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>summarize</span> <span style=''>the</span> <span style=''>input</span> <span style=''>points</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successive</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Relational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>Machines</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>Machines</span> <span style=''>(RSM)</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>accurate</span> <span style=''>and</span> <span style=''>flexible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>and</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>Despite</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style=''>learning</span> <span style=''>most</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>adapt</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>settings</span> <span style=''>due</span> <span style=''>to</span> <span style=''>issues</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>accuracy</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>for</span> <span style=''>handling</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>and</span> <span style=''>tasks</span> <span style=''>For</span> <span style=''>instance</span> <span style=''>many</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>perform</span> <span style=''>poorly</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>graphs</span> <span style=''>that</span> <span style=''>are</span> <span style=''>sparsely</span> <span style=''>labeled</span> <span style=''>or</span> <span style=''>network</span> <span style=''>data</span> <span style=''>with</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autocorrelation</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>(i)</span> <span style=''>fast</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>at</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactive</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10295689348058425)
# 	architecture (0.08300676879230495)
# 	knowledge (0.11970074812967581)
# 	experimental (0.13573209832561453)
# 	segmentation (0.07196294976843605)
# 	different (0.25970787317420735)
# 	detection (0.1257570359814749)
# 	information (0.26042037762736014)
# 	convolutional (0.13145707160669753)
# 	recognition (0.13608835055219096)
#
# Some Statistics words are:
# 	stochastic (0.13095835423983943)
# 	variables (0.13396889111891622)
# 	theoretical (0.15153035624686403)
# 	estimation (0.17059708981435023)
# 	algorithm (0.4029101856497742)
# 	statistical (0.16056196688409433)
# 	distribution (0.18615153035624687)
# 	inference (0.19769192172604114)
# 	regression (0.17611640742599097)
# 	dimensional (0.19719016557952834)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="580ec1ba-1876-49f3-985d-c754955e4e73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("580ec1ba-1876-49f3-985d-c754955e4e73")) {                    Plotly.newPlot(                        "580ec1ba-1876-49f3-985d-c754955e4e73",                        [{"x":["typically","demonstrating","empirical","curvature","asymptotic","overfitting","stochastic","performance","addressed","feedforward","averaging","inefficient","combining","properties","predictive","demonstrated","mitigates","theoretical","convolutional","preconditioned","preconditioning","effective","posterior","regression","convergence","parameter","pathological","unsupervised","introduced","traditional","representation","prediction","equivalent","reproducing","proposing","introduce","classification","applicability","supervised","competitive","reasonably","backpropagation","decoupled","supervision","multilayer","resolution","improvements","resulting","advantage","optimizing","efficiently","benchmarks","descriptor","expansion","activations","particular","compatible","employing","competing","representations","descriptors","challenging","recognition","outperformed","furthermore","outperforming","geometric","retrieval","primitive","information","significantly","guidelines","popularity","surprisingly","acquisition","notoriously","optimisation","algorithms","solutions","simulation","literature","cumulative","parameters","following","importance","optimising","estimation","reasonable","demonstrates","improvement","observation","processes","practical","application","generalization","understand","construct","corresponding","quadratic","independent","logarithmic","additivity","descriptively","constraints","individual","coordinates","sufficient","automated","characterization","conditions","associated","classified","clustered","different","classical","combination","improving","accessing","auxiliary","completely","necessary","searching","algorithm","techniques","considering","clustering","documents","abstraction","technique","available","description","quantized","excellent","augmentation","remarkable","projections","projection","quantization","including","multiplicative","projected","projecting","heuristic","robustness","specifically","binarization","distortions","distributions","passenger","extrapolation","smoothing","interpolation","framework","synthetic","covariances","atmospheric","discovering","reconstruct","performing","stationary","transform","functions","inference","demonstrate","modelling","nonparametric","discovery","structures","increasing","optimization","pyramidal","disappearance","important","gradually","experiments","structure","analysing","incoherent","principle","performed","transmission","characteristic","respectively","effectively","characteristics","therefore","quantified","analyzing","presenting","knowledge","quantitatively","generative","realistic","conditioned","dimensional","evaluation","intensive","generator","illustrate","degradation","generation","likelihood","adversarial","conditional","successfully","discriminator","recurrent","architecture","electronic","benchmarking","forecasting","multitask","outperforms","difficult","successful","leverages","heterogeneous","baselines","healthcare","formulate","frontiers","explosion","benchmark","phenotype","clinically","correlations","detecting","physiologic","mortality","additionally","separating","artificial","invariant","translation","fingerprint","fingerprints","distinguish","established","conducted","databases","discriminated","suggestions","generated","evaluating","histograms","discriminative","synthetically","workloads","facilitate","frameworks","customized","dirichlet","allocation","outperform","integration" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	preconditioned
# 	extrapolation
# 	frontiers
# 	physiologic
# 	smoothers
# 	assortment
# 	borrowings
# 	straggler
# 	replication
# 	stragglers
# 	minimizations
# 	homoscedastic
# 	asymptotics
# 	looseness
# 	minimizers
# 	coalescent
# 	precludes
# 	conformalized
# 	semiparametric
# 	nonparanormal
# Some words which never appear in Statistics papers:
# 	pyramidal
# 	disappearance
# 	discriminated
# 	formalisms
# 	sémantique
# 	syntaxique
# 	disabilities
# 	accessibility
# 	appearance
# 	collisions
# 	incidental
# 	annotator
# 	truthfulness
# 	productivity
# 	surfacing
# 	misinformation
# 	geography
# 	entertainment
# 	discerning
# 	underwater

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.064007108496492e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
